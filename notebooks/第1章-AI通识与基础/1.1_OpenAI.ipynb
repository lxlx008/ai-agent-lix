# %% [markdown]
# # OpenAI 调用大模型
#
# ## 0.准备工作
#
# 首先，我们需要安装OpenAI的依赖
# 安装命令：
# ```shell
# uv add openai
# ```

# %% [markdown]
# ## 1.初始化客户端
#
# ### 1.1.硬编码API_KEY

# %%
from openai import OpenAI

# 创建 OpenAI 客户端
client = OpenAI(
    api_key="sk-c7f54ee27e894fccbfa18a0f860a5f6c",
    base_url="https://api.deepseek.com"
)

# %% [markdown]
# ### 1.2. 从环境变量中获取API_KEY

# %% [markdown]
# 读取环境变量需要用到python-dotenv，先安装依赖
# 安装命令：
# ```shell
# uv add python-dotenv
# ```
# 再创建.env文件，并写入api_key
# ```properties
# DEEPSEEK_API_KEY=sk-f36dee1a622c5c878f13a9ca95f58297
# ```
# 接着就可以可以从环境变量中获取api_key了

# %%
from dotenv import load_dotenv
import os

load_dotenv()

api_key = os.getenv("DASHSCOPE_API_KEY")
base_url = os.getenv("DASHSCOPE_BASE_URL")
print(api_key)
print(base_url)

client=OpenAI(
    api_key=api_key,
    base_url=base_url,
)
# Out:
# sk-914a82ea121f412ea9a8c8c7b22f7792
# https://dashscope.aliyuncs.com/compatible-mode/v1

# %% [markdown]
# ## 2.访问模型

# %%
print("🚀 正在调用大模型...")
response = client.chat.completions.create(
    model="deepseek-v3.2",
    messages=[
        {"role": "system", "content": "你是一名友好的AI助教。"},
        {"role": "user", "content": "你好，你是谁?"},
        {"role": "user", "content": "你是什么版本?"},
        {"role": "user", "content": "明天是什么天气"}
    ],
    stream=False,
    temperature=0.9,
)
print("🚀 成功调用大模型...")
# Out:
# 🚀 正在调用大模型...
# 🚀 成功调用大模型...

# %% [markdown]
# ## 3.获取模型响应结果

# %%
print(response.model_dump_json(indent=2))
# Out:
# {
#   "id": "chatcmpl-7b12eb10-2aa3-9c84-81c8-7a357dbf579e",
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "logprobs": null,
#       "message": {
#         "content": "你好！我是DeepSeek，一个由深度求索公司创造的AI助手！😊\n\n关于版本信息：我是DeepSeek最新版本模型，但具体的版本号我这边没有显示。如果你想了解最准确的技术细节和版本信息，建议你查阅DeepSeek的官方文档和公告哦。\n\n至于明天的天气，这个我需要提醒你：我目前不支持实时联网搜索功能，所以无法获取最新的天气信息。如果你想了解明天的天气情况，可以：\n1. 查看手机上的天气应用\n2. 询问智能音箱或手机助手\n3. 访问天气预报网站\n\n如果你有其他我能帮助的问题，比如学习、工作、生活建议，或者需要我处理文档、回答问题等，我都很乐意为你提供帮助！✨\n\n有什么其他我可以协助你的吗？",
#         "refusal": null,
#         "role": "assistant",
#         "annotations": null,
#         "audio": null,
#         "function_call": null,
#         "tool_calls": null
#       }
#     }
#   ],
#   "created": 1774864200,
#   "model": "deepseek-v3.2",
#   "object": "chat.completion",
#   "service_tier": null,
#   "system_fingerprint": null,
#   "usage": {
#     "completion_tokens": 161,
#     "prompt_tokens": 24,
#     "total_tokens": 185,
# ...

# %%
print(response.choices[0].message.content)
# Out:
# 你好！我是DeepSeek，一个由深度求索公司创造的AI助手！😊
#
# 关于版本信息：我是DeepSeek最新版本模型，但具体的版本号我这边没有显示。如果你想了解最准确的技术细节和版本信息，建议你查阅DeepSeek的官方文档和公告哦。
#
# 至于明天的天气，这个我需要提醒你：我目前不支持实时联网搜索功能，所以无法获取最新的天气信息。如果你想了解明天的天气情况，可以：
# 1. 查看手机上的天气应用
# 2. 询问智能音箱或手机助手
# 3. 访问天气预报网站
#
# 如果你有其他我能帮助的问题，比如学习、工作、生活建议，或者需要我处理文档、回答问题等，我都很乐意为你提供帮助！✨
#
# 有什么其他我可以协助你的吗？
